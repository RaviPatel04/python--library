# %%
import numpy as np
import pandas as pd

# %%
dict = {
    "En.no" : [3, 13, 23, 33],
    "Name" : ['Karan', 'Jinal', 'Ravi', 'Rahul'],
    "Cpi" : [2, 5, 8.39, 9.20]
}

df = pd.DataFrame(dict)
df
# Out:
#    En.no   Name   Cpi
# 0      3  Karan  2.00
# 1     13  Jinal  5.00
# 2     23   Ravi  8.39
# 3     33  Rahul  9.20

# %%
dict = {
    "En.no" : [3, 13, 23, 33],
    "Name" : ['Karan', 'Jinal', 'Ravi', 'Rahul'],
    "Cpi" : [2, 5, 8.39, 9.20]
}

df = pd.DataFrame(dict)
df
# Out:
#    En.no   Name   Cpi
# 0      3  Karan  2.00
# 1     13  Jinal  5.00
# 2     23   Ravi  8.39
# 3     33  Rahul  9.20

# %%
df.to_csv('collage.csv')

# %%
df.to_csv('collage_noindex.csv',index = False)

# %%
df.head(2)
# Out:
#    En.no   Name  Cpi
# 0      3  Karan  2.0
# 1     13  Jinal  5.0

# %%
df.tail(2)
# Out:
#    En.no   Name   Cpi
# 2     23   Ravi  8.39
# 3     33  Rahul  9.20

# %%
df.describe()
# Out:
#            En.no       Cpi
# count   4.000000  4.000000
# mean   18.000000  6.147500
# std    12.909944  3.309838
# min     3.000000  2.000000
# 25%    10.500000  4.250000
# 50%    18.000000  6.695000
# 75%    25.500000  8.592500
# max    33.000000  9.200000

# %%
dict1 = {
    "Bus no" : [1313, 2323, 1323, 2313],
    "From" : ['surat', 'rajastan', 'kadi', 'ambaji'],
    "To" : ['kadi', 'surat', 'nasik', 'mumbai'],
    "price" : [281, 359, 354, 499]
}
rv = pd.DataFrame(dict1)

# %%
rv.to_csv('Bus.csv')
rv
# Out:
#    Bus no      From      To  price
# 0    1313     surat    kadi    281
# 1    2323  rajastan   surat    359
# 2    1323      kadi   nasik    354
# 3    2313    ambaji  mumbai    499

# %%
rv['price'][1] = 300
# Out:
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_6864\5184733.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rv['price'][1] = 300

# %%
rv
# Out:
#    Bus no      From      To  price
# 0    1313     surat    kadi    281
# 1    2323  rajastan   surat    300
# 2    1323      kadi   nasik    354
# 3    2313    ambaji  mumbai    499

# %%
rv.to_csv('Bus.csv')

# %%
rv.index = ['luxury', 'gurjarnagri', 'sleeper', 'Express']

# %%
rv
# Out:
#              Bus no      From      To  price
# luxury         1313     surat    kadi    281
# gurjarnagri    2323  rajastan   surat    300
# sleeper        1323      kadi   nasik    354
# Express        2313    ambaji  mumbai    499

# %%
ser = pd.Series(np.random.rand(10))

# %%
ser
# Out:
# 0    0.676255
# 1    0.794393
# 2    0.944565
# 3    0.380315
# 4    0.871861
# 5    0.151479
# 6    0.149214
# 7    0.815823
# 8    0.627804
# 9    0.196166
# dtype: float64

# %%
dataf = pd.DataFrame(np.random.rand(100, 3))

# %%
dataf
# Out:
#            0         1         2
# 0   0.383015  0.964612  0.009371
# 1   0.924201  0.829690  0.833057
# 2   0.257306  0.418219  0.083011
# 3   0.825465  0.709968  0.132226
# 4   0.339655  0.182199  0.431481
# ..       ...       ...       ...
# 95  0.205228  0.889559  0.752458
# 96  0.477555  0.884204  0.684935
# 97  0.188299  0.268678  0.458595
# 98  0.095929  0.374440  0.631454
# 99  0.393644  0.562962  0.721718
#
# [100 rows x 3 columns]

# %%
dataf.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# dtype: object

# %%
dataf.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
dataf.columns
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
dataf.to_numpy()
# Out:
# array([[0.38301465, 0.96461182, 0.00937073],
#        [0.92420075, 0.82969041, 0.83305709],
#        [0.25730634, 0.4182195 , 0.08301088],
#        [0.82546536, 0.70996759, 0.13222627],
#        [0.33965475, 0.18219939, 0.43148124],
#        [0.0211979 , 0.25911837, 0.71408619],
#        [0.0487835 , 0.88097881, 0.63719418],
#        [0.62238546, 0.80657077, 0.80454381],
#        [0.80220435, 0.66269922, 0.63855431],
#        [0.02578503, 0.69911242, 0.59012899],
#        [0.72328873, 0.22584901, 0.69034545],
#        [0.28180507, 0.43938685, 0.359653  ],
#        [0.2985593 , 0.63460255, 0.15621108],
#        [0.25856298, 0.21703117, 0.5234433 ],
#        [0.1426269 , 0.73171133, 0.99164511],
#        [0.63369802, 0.22987538, 0.89135639],
#        [0.26618795, 0.54720951, 0.91861859],
#        [0.05822058, 0.84327585, 0.07865511],
#        [0.96048406, 0.34875559, 0.99046938],
#        [0.77017532, 0.64573085, 0.44518417],
#        [0.39365473, 0.85221709, 0.25461881],
# ...

# %%
dataf.T
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.383015  0.924201  0.257306  0.825465  0.339655  0.021198  0.048784
# 1  0.964612  0.829690  0.418219  0.709968  0.182199  0.259118  0.880979
# 2  0.009371  0.833057  0.083011  0.132226  0.431481  0.714086  0.637194
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.622385  0.802204  0.025785  ...  0.051439  0.264762  0.614932  0.668121
# 1  0.806571  0.662699  0.699112  ...  0.688448  0.984791  0.985628  0.720026
# 2  0.804544  0.638554  0.590129  ...  0.237107  0.083800  0.554072  0.254653
#
#          94        95        96        97        98        99
# 0  0.465411  0.205228  0.477555  0.188299  0.095929  0.393644
# 1  0.667890  0.889559  0.884204  0.268678  0.374440  0.562962
# 2  0.342640  0.752458  0.684935  0.458595  0.631454  0.721718
#
# [3 rows x 100 columns]

# %%
dataf
# Out:
#            0         1         2
# 0   0.383015  0.964612  0.009371
# 1   0.924201  0.829690  0.833057
# 2   0.257306  0.418219  0.083011
# 3   0.825465  0.709968  0.132226
# 4   0.339655  0.182199  0.431481
# ..       ...       ...       ...
# 95  0.205228  0.889559  0.752458
# 96  0.477555  0.884204  0.684935
# 97  0.188299  0.268678  0.458595
# 98  0.095929  0.374440  0.631454
# 99  0.393644  0.562962  0.721718
#
# [100 rows x 3 columns]

# %%
dataf.sort_index(axis=0, ascending=False)
# Out:
#            0         1         2
# 99  0.393644  0.562962  0.721718
# 98  0.095929  0.374440  0.631454
# 97  0.188299  0.268678  0.458595
# 96  0.477555  0.884204  0.684935
# 95  0.205228  0.889559  0.752458
# ..       ...       ...       ...
# 4   0.339655  0.182199  0.431481
# 3   0.825465  0.709968  0.132226
# 2   0.257306  0.418219  0.083011
# 1   0.924201  0.829690  0.833057
# 0   0.383015  0.964612  0.009371
#
# [100 rows x 3 columns]

# %%
dataf.sort_index(axis=1, ascending=False)
# Out:
#            2         1         0
# 0   0.009371  0.964612  0.383015
# 1   0.833057  0.829690  0.924201
# 2   0.083011  0.418219  0.257306
# 3   0.132226  0.709968  0.825465
# 4   0.431481  0.182199  0.339655
# ..       ...       ...       ...
# 95  0.752458  0.889559  0.205228
# 96  0.684935  0.884204  0.477555
# 97  0.458595  0.268678  0.188299
# 98  0.631454  0.374440  0.095929
# 99  0.721718  0.562962  0.393644
#
# [100 rows x 3 columns]

# %%
dataf.loc[0,0]=3

# %%
dataf
# Out:
#            0         1         2
# 0   3.000000  0.964612  0.009371
# 1   0.924201  0.829690  0.833057
# 2   0.257306  0.418219  0.083011
# 3   0.825465  0.709968  0.132226
# 4   0.339655  0.182199  0.431481
# ..       ...       ...       ...
# 95  0.205228  0.889559  0.752458
# 96  0.477555  0.884204  0.684935
# 97  0.188299  0.268678  0.458595
# 98  0.095929  0.374440  0.631454
# 99  0.393644  0.562962  0.721718
#
# [100 rows x 3 columns]

# %%
dataf.columns = list("ABC")

# %%
dataf
# Out:
#            A         B         C
# 0   3.000000  0.964612  0.009371
# 1   0.924201  0.829690  0.833057
# 2   0.257306  0.418219  0.083011
# 3   0.825465  0.709968  0.132226
# 4   0.339655  0.182199  0.431481
# ..       ...       ...       ...
# 95  0.205228  0.889559  0.752458
# 96  0.477555  0.884204  0.684935
# 97  0.188299  0.268678  0.458595
# 98  0.095929  0.374440  0.631454
# 99  0.393644  0.562962  0.721718
#
# [100 rows x 3 columns]

# %%
dataf.loc[0,0]=45

# %%
dataf
# Out:
#            A         B         C     0
# 0   3.000000  0.964612  0.009371  45.0
# 1   0.924201  0.829690  0.833057   NaN
# 2   0.257306  0.418219  0.083011   NaN
# 3   0.825465  0.709968  0.132226   NaN
# 4   0.339655  0.182199  0.431481   NaN
# ..       ...       ...       ...   ...
# 95  0.205228  0.889559  0.752458   NaN
# 96  0.477555  0.884204  0.684935   NaN
# 97  0.188299  0.268678  0.458595   NaN
# 98  0.095929  0.374440  0.631454   NaN
# 99  0.393644  0.562962  0.721718   NaN
#
# [100 rows x 4 columns]

# %%
dataf.loc[0,'A'] = 13

# %%
dataf.head()
# Out:
#            A         B         C     0
# 0  13.000000  0.964612  0.009371  45.0
# 1   0.924201  0.829690  0.833057   NaN
# 2   0.257306  0.418219  0.083011   NaN
# 3   0.825465  0.709968  0.132226   NaN
# 4   0.339655  0.182199  0.431481   NaN

# %%
dataf = dataf.drop(0, axis = 1)

# %%
dataf
# Out:
#             A         B         C
# 0   13.000000  0.964612  0.009371
# 1    0.924201  0.829690  0.833057
# 2    0.257306  0.418219  0.083011
# 3    0.825465  0.709968  0.132226
# 4    0.339655  0.182199  0.431481
# ..        ...       ...       ...
# 95   0.205228  0.889559  0.752458
# 96   0.477555  0.884204  0.684935
# 97   0.188299  0.268678  0.458595
# 98   0.095929  0.374440  0.631454
# 99   0.393644  0.562962  0.721718
#
# [100 rows x 3 columns]

# %%
dataf.loc[[2,4],['B']]
# Out:
#           B
# 2  0.418219
# 4  0.182199

# %%
dataf.loc[[2,4], :]
# Out:
#           A         B         C
# 2  0.257306  0.418219  0.083011
# 4  0.339655  0.182199  0.431481

# %%
dataf
# Out:
#             A         B         C
# 0   13.000000  0.964612  0.009371
# 1    0.924201  0.829690  0.833057
# 2    0.257306  0.418219  0.083011
# 3    0.825465  0.709968  0.132226
# 4    0.339655  0.182199  0.431481
# ..        ...       ...       ...
# 95   0.205228  0.889559  0.752458
# 96   0.477555  0.884204  0.684935
# 97   0.188299  0.268678  0.458595
# 98   0.095929  0.374440  0.631454
# 99   0.393644  0.562962  0.721718
#
# [100 rows x 3 columns]

# %%
dataf.loc[(dataf['C']<0.4) & (dataf['A']>0.4) ]
# Out:
#             A         B         C
# 0   13.000000  0.964612  0.009371
# 3    0.825465  0.709968  0.132226
# 22   0.422133  0.836971  0.281673
# 23   0.731246  0.523781  0.271052
# 25   0.736396  0.341732  0.368764
# 29   0.733183  0.583003  0.136724
# 35   0.778570  0.356984  0.226863
# 37   0.584301  0.547457  0.054129
# 38   0.854259  0.182505  0.363344
# 43   0.958711  0.649951  0.278693
# 49   0.452867  0.299009  0.197334
# 53   0.790601  0.465857  0.204565
# 54   0.963271  0.332086  0.169843
# 56   0.479102  0.469005  0.346333
# 59   0.829083  0.728405  0.313649
# 62   0.590900  0.049273  0.138854
# 64   0.483982  0.407520  0.040695
# 65   0.508410  0.722666  0.374375
# 68   0.735812  0.993580  0.211316
# 69   0.720598  0.497398  0.392902
# 75   0.421828  0.574341  0.024387
# 76   0.449823  0.900452  0.101234
# 80   0.822372  0.547594  0.029819
# 81   0.745544  0.757686  0.296012
# 82   0.547473  0.312535  0.175190
# 84   0.578355  0.334677  0.373658
# ...

# %%
dataf.iloc[0,2]
# Out:
# 0.00937072975035591

# %%
dataf.head()
# Out:
#            A         B         C
# 0  13.000000  0.964612  0.009371
# 1   0.924201  0.829690  0.833057
# 2   0.257306  0.418219  0.083011
# 3   0.825465  0.709968  0.132226
# 4   0.339655  0.182199  0.431481

# %%
dataf.iloc[[0,2],[0]]
# Out:
#            A
# 0  13.000000
# 2   0.257306

# %%
dataf.drop([0,2], axis=0, inplace=True)

# %%
dataf.head()
# Out:
#           A         B         C
# 1  0.924201  0.829690  0.833057
# 3  0.825465  0.709968  0.132226
# 4  0.339655  0.182199  0.431481
# 5  0.021198  0.259118  0.714086
# 6  0.048784  0.880979  0.637194

# %%
dataf.reset_index()
# Out:
#     index         A         B         C
# 0       1  0.924201  0.829690  0.833057
# 1       3  0.825465  0.709968  0.132226
# 2       4  0.339655  0.182199  0.431481
# 3       5  0.021198  0.259118  0.714086
# 4       6  0.048784  0.880979  0.637194
# ..    ...       ...       ...       ...
# 93     95  0.205228  0.889559  0.752458
# 94     96  0.477555  0.884204  0.684935
# 95     97  0.188299  0.268678  0.458595
# 96     98  0.095929  0.374440  0.631454
# 97     99  0.393644  0.562962  0.721718
#
# [98 rows x 4 columns]

# %%
dataf.reset_index(drop=True, inplace = True)

# %%
dataf
# Out:
#            A         B         C
# 0   0.924201  0.829690  0.833057
# 1   0.825465  0.709968  0.132226
# 2   0.339655  0.182199  0.431481
# 3   0.021198  0.259118  0.714086
# 4   0.048784  0.880979  0.637194
# ..       ...       ...       ...
# 93  0.205228  0.889559  0.752458
# 94  0.477555  0.884204  0.684935
# 95  0.188299  0.268678  0.458595
# 96  0.095929  0.374440  0.631454
# 97  0.393644  0.562962  0.721718
#
# [98 rows x 3 columns]

# %%
dataf.loc[2:6, ['A']] = 13
dataf.loc[2:6, ['C']] = 23

# %%
dataf
# Out:
#             A         B          C
# 0    0.924201  0.829690   0.833057
# 1    0.825465  0.709968   0.132226
# 2   13.000000  0.182199  23.000000
# 3   13.000000  0.259118  23.000000
# 4   13.000000  0.880979  23.000000
# ..        ...       ...        ...
# 93   0.205228  0.889559   0.752458
# 94   0.477555  0.884204   0.684935
# 95   0.188299  0.268678   0.458595
# 96   0.095929  0.374440   0.631454
# 97   0.393644  0.562962   0.721718
#
# [98 rows x 3 columns]

# %%
dfex = pd.read_excel('newbus.xlsx')

# %%
dfex
# Out:
#    Bus no      From      To  price
# 0    2222     surat    kadi    433
# 1    3333  rajastan   surat    212
# 2    4444      kadi   nasik    342
# 3    6666    ambaji  mumbai    222

# %%
dfex = pd.read_excel('newbus.xlsx', sheet_name = 'sheet2')

# %%
dfex
# Out:
#    Bus no      From      To  price
# 0    1313     surat    kadi    281
# 1    2323  rajastan   surat    300
# 2    1323      kadi   nasik    354
# 3    2313    ambaji  mumbai    499
