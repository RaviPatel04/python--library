# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4]
y = [4,3,2,1]
plt.step(x,y)
plt.show()

# %%
x = [1,2,3,4,5]
y = [2,1,5,3,4]
plt.step(x,y,marker = "*",color = "k",mfc = "r",ms = 8,label = "S_p")
plt.legend()
plt.title("Step plot")
plt.grid()
plt.show()
