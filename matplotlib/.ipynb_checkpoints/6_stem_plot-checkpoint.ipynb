# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]
y = [3,2,5,4,1]
plt.stem(x,y)
plt.show()

# %%
x = [1,2,3,4,5,3.5]
y = [3,2,5,4,1,-3]
plt.stem(x,y,linefmt = ":",markerfmt = "r*",basefmt = "b",use_line_collection=False)
plt.show()
# Out:
# C:\Users\Ravi\AppData\Local\Temp\ipykernel_3600\1307025682.py:3: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(x,y,linefmt = ":",markerfmt = "r*",basefmt = "b",use_line_collection=False)
