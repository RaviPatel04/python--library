# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]
y = [2,5,1,4,3]
plt.plot(x,y,color = "k")
plt.savefig("linear")
plt.show()

# %%
x = [1,2,3,4,5]
y = [2,5,1,4,3]
plt.plot(x,y,color = "k")
plt.savefig("linear1",dpi = 1500 , facecolor = "r")
plt.show()
