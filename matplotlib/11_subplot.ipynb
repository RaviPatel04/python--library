# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4]
y = [2,1,4,3]

plt.subplot(2,2,1)
plt.plot(x,y,color = "r")

plt.subplot(2,2,2)
plt.pie(x,autopct = "%0.0f%%")

plt.subplot(2,2,3)
plt.bar(x,y)

plt.subplot(2,2,4)
plt.scatter(x,y)
plt.show()
